# %%
open(INPUT, "<", "4_11_all_SSYT_one_column_removing_frozen_factors_WTS.txt");            #inputing the file containing weight vectors from sage computation
$matrix=new Matrix<Integer>(<INPUT>);     
close(INPUT);
#print $matrix;


open(INPUT, "<", "GR_4_11_SSYT_one_column.txt");       #inputing the file containing the entries of SSYT as an array 
$array=new Array<Array<Int>>(<INPUT>);
close(INPUT);
#print $array;

# %%
$p = hypersimplex(4,11);
# input of the hypersimplex 

$M = new Matrix($p->VERTICES);

@ar = ();             #array to store subdivisions for each weight vector

$r = $matrix->rows();   #number of weight vectors from sage computation

for(my $i=0; $i < $r; $i++){
$wt = $matrix->[$i];
$S = new fan::SubdivisionOfPoints(POINTS=>$p->VERTICES,WEIGHTS=>$wt); # parse the particular weight vector in this command to get the subdivision
#print $S->N_MAXIMAL_CELLS;
#push @ar, $S;
$n = $S->N_MAXIMAL_CELLS;
$c = 0;

for(my $i = 0; $i < $n; $i++){
my $v = $S->MAXIMAL_CELLS->[$i];
my $M1 = $M->minor($v, All);
my $p1 = new Polytope(POINTS=>$M1);
my $pos1 = matroid::matroid_from_matroid_polytope($p1);
if($pos1->POSITROID == true){
$c = $c +1;
}
}


if($c == $n){
print "Subdivision is positroidal\n";                 #pushing the subdivision as an element in the array
push @ar, $S;
}

}
# Out:
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# Subdivision is positroidal
# ...

# %%
@sp=();                      #array to store indices of SSYT which correspond to splits 

$d = 0;
for(my $i=0; $i < $r; $i++){
$sub = $ar[$i];
#print $ar[$i]->N_MAXIMAL_CELLS;
if($sub->N_MAXIMAL_CELLS ==2){
push @sp, $i;
}
}

$l = scalar(@sp);
for(my $i=0; $i < $l; $i++){
print "$array->[$sp[$i]]\n";
#print "$sp[$i]\n";
}
# Out:
# 1 2 3 8
# 1 2 3 9
# 1 2 4 7
# 1 2 5 6
# 1 2 5 10
# 1 2 5 11
# 1 2 6 7
# 1 2 6 11
# 1 2 7 9
# 1 3 5 10
# 1 3 5 11
# 1 3 6 7
# 1 3 7 11
# 1 3 8 10
# 1 3 8 11
# 1 3 9 10
# 1 3 9 11
# 1 4 5 7
# 1 4 6 10
# 1 4 7 8
# 1 4 7 11
# 1 5 6 7
# 1 5 8 9
# 1 5 8 10
# 1 5 9 11
# 1 6 7 9
# 1 6 7 11
# 1 6 8 9
# 1 6 9 11
# 1 6 10 11
# 1 7 8 9
# 1 7 9 10
# 1 7 10 11
# 2 3 4 7
# 2 3 5 9
# 2 3 5 10
# 2 3 7 8
# 2 3 8 9
# 2 3 8 11
# 2 3 10 11
# 2 4 5 9
# 2 4 6 7
# 2 4 6 8
# 2 4 7 8
# 2 4 7 9
# 2 4 7 10
# 2 4 8 9
# 2 4 8 11
# 2 5 6 9
# 2 5 7 8
# 2 5 7 11
# 2 5 8 9
# 2 5 8 11
# 2 5 9 10
# 2 6 7 10
# 2 6 8 10
# 2 7 9 10
# 2 8 9 11
# 3 4 5 10
# 3 4 8 11
# 3 4 9 11
# 3 5 6 7
# 3 5 6 10
# 3 5 6 11
# 3 5 7 8
# 3 5 7 10
# 3 5 8 9
# 3 5 8 10
# 3 6 7 8
# 3 6 9 10
# 3 7 8 9
# 4 5 6 11
# 4 5 7 9
# 4 5 8 9
# 4 5 8 10
# 4 5 8 11
# 4 5 9 11
# 4 5 10 11
# 4 6 7 11
# 4 6 8 9
# 4 6 8 10
# 4 6 10 11
# 4 7 9 10
# 4 7 9 11
# 4 7 10 11
# 4 8 9 10
# 5 6 7 11
# 5 6 8 10
# 5 6 9 11
# 5 6 10 11
# 5 7 8 10
# 5 7 8 11
# 5 7 9 11
# ...

# %%
print scalar(@sp);
# Out:
# 99

# %%
@spl = ();

$c = 0;
$l = scalar(@sp);
for(my $i=0; $i < $l; $i++){